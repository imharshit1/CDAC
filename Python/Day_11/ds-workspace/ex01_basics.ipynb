# %% [markdown]
# # Introduction to Pandas

# %%
# test_setup.py
import sys
import pandas as pd
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
print(f"Python Version:     {sys.version.split()[0]}")
print(f"Pandas Version:     {pd.__version__}")
print(f"Matplotlib Version: {matplotlib.__version__}")
print(f"Seaborn Version:    {sns.__version__}")
print("\nEnvironment is ready for Data Science!")
# Out:
# Python Version:     3.14.3
# Pandas Version:     3.0.5
# Matplotlib Version: 3.11.1
# Seaborn Version:    0.13.2
#
# Environment is ready for Data Science!

# %%
df = pd.read_csv("data/sales.csv")
print(f'{type(df) = }')
# print([d for d in dir(df) if not d.startswith('_')])
print(f'{df.shape = }')
df.info()
# Out:
# type(df) = <class 'pandas.DataFrame'>
# df.shape = (1000, 18)
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Invoice Number          1000 non-null   int64
#  1   Date                    1000 non-null   str
#  2   Time                    1000 non-null   str
#  3   Internal Toy ID Number  1000 non-null   str
#  4   Toy Item Number         1000 non-null   int64
#  5   Toy Company             1000 non-null   str
#  6   Toy Name                1000 non-null   str
#  7   Suggested Age           1000 non-null   str
#  8   Price Per Toy           1000 non-null   str
#  9   Units Sold              1000 non-null   int64
#  10  Total Line Revenue      1000 non-null   str
#  11  Total COGS              1000 non-null   str
#  12  Payment                 1000 non-null   str
#  13  Cashier ID              1000 non-null   str
#  14  Member?                 1000 non-null   str
#  15  Coupon?                 1000 non-null   str
#  16  Purchaser Age           1000 non-null   int64
#  17  Parking Validation?     1000 non-null   str
# dtypes: int64(4), str(14)
# memory usage: 140.8 KB

# %%
df.head()
# Out:
#    Invoice Number       Date   Time Internal Toy ID Number  Toy Item Number  \
# 0          654522   1/7/2010  10:25                D255/FE              192
# 1          654526   1/7/2010  12:00                L217/SN              255
# 2          654568   1/7/2010  14:19                L195/AE              195
# 3          654576  1/25/2010  12:57                L256/PE              256
# 4          654613   2/5/2010  14:51                D250/AT              192
#
#   Toy Company                        Toy Name Suggested Age Price Per Toy  \
# 0       Duplo                       Policemen      6 and up        $9.95
# 1       Duplo                   Farming Scene      7 and up       $24.95
# 2        Lego                        Airplane      8 and up        $5.95
# 3        Lego  Police Officers and Motorcycle      9 and up        $9.95
# 4       Duplo                       Policemen      6 and up        $9.95
#
#    Units Sold Total Line Revenue Total COGS   Payment     Cashier ID Member?  \
# 0           1             $9.95      $5.17       Cash  V.W.|880-4523      No
# 1           5           $124.75     $81.10       Visa  B.X.|880-9149      No
# 2           1             $5.95      $3.09       Cash  Z.Q.|880-4240      No
# 3           1             $9.95      $4.48   Discover  D.U.|880-2953      No
# 4           1             $9.95      $5.17       Cash  D.Z.|880-1179      No
#
#   Coupon?  Purchaser Age Parking Validation?
# 0      No             39                  No
# 1      No             29                  No
# 2     Yes             46                 Yes
# 3      No             36                  No
# 4      No             33                  No

# %%
df.tail(10)
# Out:
#      Invoice Number        Date   Time Internal Toy ID Number  \
# 990          674444  12/23/2012  16:10                D250/AT
# 991          674445  12/23/2012  15:45                L256/PE
# 992          674445  12/23/2012  15:45                D250/AT
# 993          674481  12/24/2012  12:59                D250/AT
# 994          674524  12/24/2012  16:58                L196/AR
# 995          674560  12/25/2012  12:49                D254/FE
# 996          674575  12/25/2012  18:46                L197/FS
# 997          674624  12/25/2012  11:33                L195/AE
# 998          674655  12/25/2012  15:33                L256/PE
# 999          674655  12/25/2012  15:33                D254/FE
#
#      Toy Item Number Toy Company                        Toy Name  \
# 990              192       Duplo                       Policemen
# 991              256        Lego  Police Officers and Motorcycle
# 992              192       Duplo                       Policemen
# 993              192       Duplo                       Policemen
# 994              196        Lego                     Antique Car
# 995              192       Duplo                       Policemen
# 996              199       Duplo                         Scooter
# 997              195        Lego                        Airplane
# 998              256        Lego  Police Officers and Motorcycle
# 999              192       Duplo                       Policemen
#
#     Suggested Age Price Per Toy  Units Sold Total Line Revenue Total COGS  \
# 990      6 and up        $9.95            1             $9.95      $5.17
# 991      9 and up        $9.95            1             $9.95      $4.48
# 992      6 and up        $9.95            1             $9.95      $5.17
# 993      6 and up        $9.95            1             $9.95      $5.17
# 994      8 and up        $7.95            1             $7.95      $4.45
# 995      6 and up        $9.95            2            $19.90     $10.34
# 996      4 and up        $4.95            5            $24.75     $12.60
# 997      8 and up        $5.95            1             $5.95      $3.09
# 998      9 and up        $9.95            2            $19.90      $8.96
# 999      6 and up        $9.95            1             $9.95      $5.17
#
#         Payment     Cashier ID Member? Coupon?  Purchaser Age  \
# 990  Mastercard  Y.P.|880-6894     Yes      No             30
# 991    Discover  W.B.|880-9647      No      No             56
# 992    Discover  W.B.|880-9647      No      No             56
# 993        Cash  Z.T.|880-7477      No      No             41
# 994  Mastercard  W.B.|880-9647      No      No             38
# 995       Check  V.W.|880-8599      No      No             23
# 996        Cash  L.C.|880-6872      No      No             35
# 997        Cash  L.W.|880-4986      No      No             32
# 998  Mastercard  S.V.|880-5987      No      No             48
# 999  Mastercard  S.V.|880-5987      No      No             48
#
#     Parking Validation?
# 990                  No
# 991                  No
# 992                  No
# 993                  No
# 994                 Yes
# 995                  No
# 996                  No
# 997                  No
# 998                  No
# 999                  No

# %%
df['Toy Name']
# Out:
# 0                           Policemen
# 1                       Farming Scene
# 2                            Airplane
# 3      Police Officers and Motorcycle
# 4                           Policemen
#                     ...
# 995                         Policemen
# 996                           Scooter
# 997                          Airplane
# 998    Police Officers and Motorcycle
# 999                         Policemen
# Name: Toy Name, Length: 1000, dtype: str

# %%
df[['Toy Name', 'Total COGS']]
# Out:
#                            Toy Name Total COGS
# 0                         Policemen     $5.17
# 1                     Farming Scene    $81.10
# 2                          Airplane     $3.09
# 3    Police Officers and Motorcycle     $4.48
# 4                         Policemen     $5.17
# ..                              ...        ...
# 995                       Policemen    $10.34
# 996                         Scooter    $12.60
# 997                        Airplane     $3.09
# 998  Police Officers and Motorcycle     $8.96
# 999                       Policemen     $5.17
#
# [1000 rows x 2 columns]

# %%
toy_series = df["Toy Name"]
print(f'{type(toy_series) = }')

df1 = df[["Toy Name", "Total COGS"]]
print(f'{type(df1) = }')
# Out:
# type(toy_series) = <class 'pandas.Series'>
# type(df1) = <class 'pandas.DataFrame'>

# %%
df[["Invoice Number", "Toy Name", "Units Sold"]].head()
# Out:
#    Invoice Number                        Toy Name  Units Sold
# 0          654522                       Policemen           1
# 1          654526                   Farming Scene           5
# 2          654568                        Airplane           1
# 3          654576  Police Officers and Motorcycle           1
# 4          654613                       Policemen           1

# %%
print(df.isnull().sum())
# Out:
# Invoice Number            0
# Date                      0
# Time                      0
# Internal Toy ID Number    0
# Toy Item Number           0
# Toy Company               0
# Toy Name                  0
# Suggested Age             0
# Price Per Toy             0
# Units Sold                0
# Total Line Revenue        0
# Total COGS                0
# Payment                   0
# Cashier ID                0
# Member?                   0
# Coupon?                   0
# Purchaser Age             0
# Parking Validation?       0
# dtype: int64

# %%
print(df.describe())
# Out:
#        Invoice Number  Toy Item Number   Units Sold  Purchaser Age
# count     1000.000000      1000.000000  1000.000000    1000.000000
# mean    664633.832000       207.054000     1.846000      37.165000
# std       5865.023157        29.249558     1.178844      10.418941
# min     654522.000000       192.000000     1.000000       6.000000
# 25%     659609.750000       192.000000     1.000000      31.000000
# 50%     664736.000000       192.000000     1.000000      36.000000
# 75%     669570.500000       195.000000     2.000000      42.000000
# max     674655.000000       340.000000     5.000000      75.000000

# %%
df.loc[0:10:2, ["Toy Company", "Toy Name", "Total COGS"]]
# Out:
#    Toy Company   Toy Name Total COGS
# 0        Duplo  Policemen     $5.17
# 2         Lego   Airplane     $3.09
# 4        Duplo  Policemen     $5.17
# 6        Duplo  Policemen     $5.17
# 8         Lego   Airplane     $3.09
# 10       Duplo  Policemen     $5.17

# %%
df[df["Units Sold"] >= 4]
# Out:
#      Invoice Number        Date   Time Internal Toy ID Number  \
# 1            654526    1/7/2010  12:00                L217/SN
# 5            654624    2/5/2010  14:36                D250/AT
# 9            654673   2/20/2010  15:27                L256/PE
# 33           655281    6/1/2010  15:27                D255/FE
# 40           655412   6/24/2010  11:39                D254/FE
# ..              ...         ...    ...                    ...
# 969          674126  12/17/2012  17:33                L195/AE
# 971          674171  12/17/2012  15:54                L195/AE
# 980          674306  12/20/2012  12:37                D255/FE
# 981          674332  12/20/2012  15:12                L340/FS
# 996          674575  12/25/2012  18:46                L197/FS
#
#      Toy Item Number Toy Company                        Toy Name  \
# 1                255       Duplo                   Farming Scene
# 5                192       Duplo                       Policemen
# 9                256        Lego  Police Officers and Motorcycle
# 33               192       Duplo                       Policemen
# 40               192       Duplo                       Policemen
# ..               ...         ...                             ...
# 969              195        Lego                        Airplane
# 971              195        Lego                        Airplane
# 980              192       Duplo                       Policemen
# 981              340        Lego                     Fire Trucks
# 996              199       Duplo                         Scooter
#
#     Suggested Age Price Per Toy  Units Sold Total Line Revenue Total COGS  \
# 1        7 and up       $24.95            5           $124.75     $81.10
# 5        6 and up        $9.95            5            $49.75     $25.85
# 9        9 and up        $9.95            4            $39.80     $17.92
# 33       6 and up        $9.95            4            $39.80     $20.68
# 40       6 and up        $9.95            5            $49.75     $25.85
# ..            ...           ...         ...                ...        ...
# 969      8 and up        $5.95            4            $23.80     $12.36
# 971      8 and up        $5.95            4            $23.80     $12.36
# 980      6 and up        $9.95            4            $39.80     $20.68
# 981      6 and up       $34.95            4           $139.80     $79.68
# 996      4 and up        $4.95            5            $24.75     $12.60
#
#         Payment     Cashier ID Member? Coupon?  Purchaser Age  \
# 1          Visa  B.X.|880-9149      No      No             29
# 5          Cash  L.W.|880-4986      No      No             47
# 9          Cash  W.B.|880-9647      No      No             32
# 33   Mastercard  W.C.|880-4861      No      No             34
# 40   Mastercard  H.B.|880-3254      No      No             65
# ..          ...            ...     ...     ...            ...
# 969        Cash  U.W.|880-9683      No      No             31
# 971        Visa  D.Z.|880-1179      No     Yes             28
# 980        Cash  A.U.|880-2167     Yes      No             24
# 981        Cash  D.W.|880-7199      No      No             37
# 996        Cash  L.C.|880-6872      No      No             35
#
#     Parking Validation?
# 1                    No
# 5                    No
# 9                    No
# 33                  Yes
# 40                   No
# ..                  ...
# 969                  No
# 971                 Yes
# 980                  No
# 981                  No
# 996                  No
#
# [145 rows x 18 columns]

# %%
duplo_members = df[(df["Toy Company"] == "Duplo") & (df["Member?"] == "Yes")]
duplo_members
# Out:
#      Invoice Number        Date   Time Internal Toy ID Number  \
# 14           654799    4/3/2010  15:27                D255/FE
# 16           654834    4/9/2010  12:06                D254/FE
# 27           655112    5/4/2010  14:47                D255/FE
# 29           655165   5/30/2010  17:40                D250/AT
# 53           655661    8/9/2010  16:56                D250/AT
# ..              ...         ...    ...                    ...
# 893          672630   12/4/2012  12:08                D255/FE
# 894          672630   12/4/2012  12:08                D255/FE
# 973          674195  12/18/2012  18:39                D255/FE
# 980          674306  12/20/2012  12:37                D255/FE
# 990          674444  12/23/2012  16:10                D250/AT
#
#      Toy Item Number Toy Company   Toy Name Suggested Age Price Per Toy  \
# 14               192       Duplo  Policemen      6 and up        $9.95
# 16               192       Duplo  Policemen      6 and up        $9.95
# 27               192       Duplo  Policemen      6 and up        $9.95
# 29               192       Duplo  Policemen      6 and up        $9.95
# 53               192       Duplo  Policemen      6 and up        $9.95
# ..               ...         ...        ...           ...           ...
# 893              192       Duplo  Policemen      6 and up        $9.95
# 894              192       Duplo  Policemen      6 and up        $9.95
# 973              192       Duplo  Policemen      6 and up        $9.95
# 980              192       Duplo  Policemen      6 and up        $9.95
# 990              192       Duplo  Policemen      6 and up        $9.95
#
#      Units Sold Total Line Revenue Total COGS     Payment     Cashier ID  \
# 14            3            $29.85     $15.51         Cash  A.U.|880-2167
# 16            2            $19.90     $10.34         Visa  Z.Q.|880-4240
# 27            1             $9.95      $5.17         Visa  H.B.|880-3254
# 29            2            $19.90     $10.34         Cash  D.U.|880-2953
# 53            1             $9.95      $5.17   Mastercard  C.X.|880-3590
# ..          ...                ...        ...         ...            ...
# 893           2            $19.90     $10.34   Mastercard  S.Y.|880-3139
# 894           1             $9.95      $5.17   Mastercard  S.Y.|880-3139
# 973           1             $9.95      $5.17     Discover  W.C.|880-4861
# 980           4            $39.80     $20.68         Cash  A.U.|880-2167
# 990           1             $9.95      $5.17   Mastercard  Y.P.|880-6894
#
#     Member? Coupon?  Purchaser Age Parking Validation?
# 14      Yes      No             47                  No
# 16      Yes     Yes             49                  No
# 27      Yes     Yes             31                  No
# 29      Yes     Yes             29                  No
# 53      Yes     Yes             34                  No
# ..      ...     ...            ...                 ...
# 893     Yes      No             31                  No
# 894     Yes      No             31                  No
# 973     Yes     Yes             38                  No
# 980     Yes      No             24                  No
# 990     Yes      No             30                  No
#
# [76 rows x 18 columns]

# %%
df['Total COGS'] = df['Total COGS'].astype(str).str.replace("$", "", regex=False).str.strip().astype(float)

# %%
df
# Out:
#      Invoice Number        Date   Time Internal Toy ID Number  \
# 0            654522    1/7/2010  10:25                D255/FE
# 1            654526    1/7/2010  12:00                L217/SN
# 2            654568    1/7/2010  14:19                L195/AE
# 3            654576   1/25/2010  12:57                L256/PE
# 4            654613    2/5/2010  14:51                D250/AT
# ..              ...         ...    ...                    ...
# 995          674560  12/25/2012  12:49                D254/FE
# 996          674575  12/25/2012  18:46                L197/FS
# 997          674624  12/25/2012  11:33                L195/AE
# 998          674655  12/25/2012  15:33                L256/PE
# 999          674655  12/25/2012  15:33                D254/FE
#
#      Toy Item Number Toy Company                        Toy Name  \
# 0                192       Duplo                       Policemen
# 1                255       Duplo                   Farming Scene
# 2                195        Lego                        Airplane
# 3                256        Lego  Police Officers and Motorcycle
# 4                192       Duplo                       Policemen
# ..               ...         ...                             ...
# 995              192       Duplo                       Policemen
# 996              199       Duplo                         Scooter
# 997              195        Lego                        Airplane
# 998              256        Lego  Police Officers and Motorcycle
# 999              192       Duplo                       Policemen
#
#     Suggested Age Price Per Toy  Units Sold Total Line Revenue  Total COGS  \
# 0        6 and up        $9.95            1             $9.95         5.17
# 1        7 and up       $24.95            5           $124.75        81.10
# 2        8 and up        $5.95            1             $5.95         3.09
# 3        9 and up        $9.95            1             $9.95         4.48
# 4        6 and up        $9.95            1             $9.95         5.17
# ..            ...           ...         ...                ...         ...
# 995      6 and up        $9.95            2            $19.90        10.34
# 996      4 and up        $4.95            5            $24.75        12.60
# 997      8 and up        $5.95            1             $5.95         3.09
# 998      9 and up        $9.95            2            $19.90         8.96
# 999      6 and up        $9.95            1             $9.95         5.17
#
#         Payment     Cashier ID Member? Coupon?  Purchaser Age  \
# 0          Cash  V.W.|880-4523      No      No             39
# 1          Visa  B.X.|880-9149      No      No             29
# 2          Cash  Z.Q.|880-4240      No     Yes             46
# 3      Discover  D.U.|880-2953      No      No             36
# 4          Cash  D.Z.|880-1179      No      No             33
# ..          ...            ...     ...     ...            ...
# 995       Check  V.W.|880-8599      No      No             23
# 996        Cash  L.C.|880-6872      No      No             35
# 997        Cash  L.W.|880-4986      No      No             32
# 998  Mastercard  S.V.|880-5987      No      No             48
# 999  Mastercard  S.V.|880-5987      No      No             48
#
#     Parking Validation?
# 0                    No
# 1                    No
# 2                   Yes
# 3                    No
# 4                    No
# ..                  ...
# 995                  No
# 996                  No
# 997                  No
# 998                  No
# 999                  No
#
# [1000 rows x 18 columns]

# %%
currency_cols = ["Price Per Toy", "Total Line Revenue"]
for col in currency_cols:
    df[col] = df[col].astype(str).str.replace("$", "", regex=False).str.strip().astype(float)

# %%
df
# Out:
#      Invoice Number        Date   Time Internal Toy ID Number  \
# 0            654522    1/7/2010  10:25                D255/FE
# 1            654526    1/7/2010  12:00                L217/SN
# 2            654568    1/7/2010  14:19                L195/AE
# 3            654576   1/25/2010  12:57                L256/PE
# 4            654613    2/5/2010  14:51                D250/AT
# ..              ...         ...    ...                    ...
# 995          674560  12/25/2012  12:49                D254/FE
# 996          674575  12/25/2012  18:46                L197/FS
# 997          674624  12/25/2012  11:33                L195/AE
# 998          674655  12/25/2012  15:33                L256/PE
# 999          674655  12/25/2012  15:33                D254/FE
#
#      Toy Item Number Toy Company                        Toy Name  \
# 0                192       Duplo                       Policemen
# 1                255       Duplo                   Farming Scene
# 2                195        Lego                        Airplane
# 3                256        Lego  Police Officers and Motorcycle
# 4                192       Duplo                       Policemen
# ..               ...         ...                             ...
# 995              192       Duplo                       Policemen
# 996              199       Duplo                         Scooter
# 997              195        Lego                        Airplane
# 998              256        Lego  Police Officers and Motorcycle
# 999              192       Duplo                       Policemen
#
#     Suggested Age  Price Per Toy  Units Sold  Total Line Revenue  Total COGS  \
# 0        6 and up           9.95           1                9.95        5.17
# 1        7 and up          24.95           5              124.75       81.10
# 2        8 and up           5.95           1                5.95        3.09
# 3        9 and up           9.95           1                9.95        4.48
# 4        6 and up           9.95           1                9.95        5.17
# ..            ...            ...         ...                 ...         ...
# 995      6 and up           9.95           2               19.90       10.34
# 996      4 and up           4.95           5               24.75       12.60
# 997      8 and up           5.95           1                5.95        3.09
# 998      9 and up           9.95           2               19.90        8.96
# 999      6 and up           9.95           1                9.95        5.17
#
#         Payment     Cashier ID Member? Coupon?  Purchaser Age  \
# 0          Cash  V.W.|880-4523      No      No             39
# 1          Visa  B.X.|880-9149      No      No             29
# 2          Cash  Z.Q.|880-4240      No     Yes             46
# 3      Discover  D.U.|880-2953      No      No             36
# 4          Cash  D.Z.|880-1179      No      No             33
# ..          ...            ...     ...     ...            ...
# 995       Check  V.W.|880-8599      No      No             23
# 996        Cash  L.C.|880-6872      No      No             35
# 997        Cash  L.W.|880-4986      No      No             32
# 998  Mastercard  S.V.|880-5987      No      No             48
# 999  Mastercard  S.V.|880-5987      No      No             48
#
#     Parking Validation?
# 0                    No
# 1                    No
# 2                   Yes
# 3                    No
# 4                    No
# ..                  ...
# 995                  No
# 996                  No
# 997                  No
# 998                  No
# 999                  No
#
# [1000 rows x 18 columns]

# %%
df['Profit Percent'] = (df['Total Line Revenue'] - df['Total COGS']) / df['Total Line Revenue'] * 100

# %%
df['Profit'] = df['Total Line Revenue'] - df['Total COGS']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Invoice Number          1000 non-null   int64
#  1   Date                    1000 non-null   str
#  2   Time                    1000 non-null   str
#  3   Internal Toy ID Number  1000 non-null   str
#  4   Toy Item Number         1000 non-null   int64
#  5   Toy Company             1000 non-null   str
#  6   Toy Name                1000 non-null   str
#  7   Suggested Age           1000 non-null   str
#  8   Price Per Toy           1000 non-null   float64
#  9   Units Sold              1000 non-null   int64
#  10  Total Line Revenue      1000 non-null   float64
#  11  Total COGS              1000 non-null   float64
#  12  Payment                 1000 non-null   str
#  13  Cashier ID              1000 non-null   str
#  14  Member?                 1000 non-null   str
#  15  Coupon?                 1000 non-null   str
#  16  Purchaser Age           1000 non-null   int64
#  17  Parking Validation?     1000 non-null   str
#  18  Profit Percent          1000 non-null   float64
#  19  Profit                  1000 non-null   float64
# dtypes: float64(5), int64(4), str(11)
# memory usage: 156.4 KB

# %%
df[['Toy Name', 'Profit']]
# Out:
#                            Toy Name  Profit
# 0                         Policemen    4.78
# 1                     Farming Scene   43.65
# 2                          Airplane    2.86
# 3    Police Officers and Motorcycle    5.47
# 4                         Policemen    4.78
# ..                              ...     ...
# 995                       Policemen    9.56
# 996                         Scooter   12.15
# 997                        Airplane    2.86
# 998  Police Officers and Motorcycle   10.94
# 999                       Policemen    4.78
#
# [1000 rows x 2 columns]

# %%
df["Toy Name"].value_counts()
# Out:
# Toy Name
# Policemen                         560
# Airplane                          187
# Police Officers and Motorcycle    164
# Farming Scene                      19
# Scooter                            14
# Antique Car                        11
# Family                             10
# Cowboys with Horses                10
# Gas Station                         9
# Scooter and Stand                   9
# Fire Trucks                         7
# Name: count, dtype: int64

# %%
df["Total Line Revenue"].sum()
# Out:
# np.float64(17965.699999999997)

# %%
df.groupby('Toy Company')["Total Line Revenue"].sum()
# Out:
# Toy Company
# Duplo    11071.35
# Lego      6894.35
# Name: Total Line Revenue, dtype: float64

# %%
df.groupby('Toy Name')["Total Line Revenue"].sum()
# Out:
# Toy Name
# Airplane                          2171.75
# Antique Car                        119.25
# Cowboys with Horses                189.00
# Family                             224.25
# Farming Scene                      948.10
# Fire Trucks                        489.30
# Gas Station                        527.20
# Police Officers and Motorcycle    3084.50
# Policemen                         9950.00
# Scooter                            173.25
# Scooter and Stand                   89.10
# Name: Total Line Revenue, dtype: float64

# %%
df
# Out:
#      Invoice Number        Date   Time Internal Toy ID Number  \
# 0            654522    1/7/2010  10:25                D255/FE
# 1            654526    1/7/2010  12:00                L217/SN
# 2            654568    1/7/2010  14:19                L195/AE
# 3            654576   1/25/2010  12:57                L256/PE
# 4            654613    2/5/2010  14:51                D250/AT
# ..              ...         ...    ...                    ...
# 995          674560  12/25/2012  12:49                D254/FE
# 996          674575  12/25/2012  18:46                L197/FS
# 997          674624  12/25/2012  11:33                L195/AE
# 998          674655  12/25/2012  15:33                L256/PE
# 999          674655  12/25/2012  15:33                D254/FE
#
#      Toy Item Number Toy Company                        Toy Name  \
# 0                192       Duplo                       Policemen
# 1                255       Duplo                   Farming Scene
# 2                195        Lego                        Airplane
# 3                256        Lego  Police Officers and Motorcycle
# 4                192       Duplo                       Policemen
# ..               ...         ...                             ...
# 995              192       Duplo                       Policemen
# 996              199       Duplo                         Scooter
# 997              195        Lego                        Airplane
# 998              256        Lego  Police Officers and Motorcycle
# 999              192       Duplo                       Policemen
#
#     Suggested Age  Price Per Toy  Units Sold  Total Line Revenue  Total COGS  \
# 0        6 and up           9.95           1                9.95        5.17
# 1        7 and up          24.95           5              124.75       81.10
# 2        8 and up           5.95           1                5.95        3.09
# 3        9 and up           9.95           1                9.95        4.48
# 4        6 and up           9.95           1                9.95        5.17
# ..            ...            ...         ...                 ...         ...
# 995      6 and up           9.95           2               19.90       10.34
# 996      4 and up           4.95           5               24.75       12.60
# 997      8 and up           5.95           1                5.95        3.09
# 998      9 and up           9.95           2               19.90        8.96
# 999      6 and up           9.95           1                9.95        5.17
#
#         Payment     Cashier ID Member? Coupon?  Purchaser Age  \
# 0          Cash  V.W.|880-4523      No      No             39
# 1          Visa  B.X.|880-9149      No      No             29
# 2          Cash  Z.Q.|880-4240      No     Yes             46
# 3      Discover  D.U.|880-2953      No      No             36
# 4          Cash  D.Z.|880-1179      No      No             33
# ..          ...            ...     ...     ...            ...
# 995       Check  V.W.|880-8599      No      No             23
# 996        Cash  L.C.|880-6872      No      No             35
# 997        Cash  L.W.|880-4986      No      No             32
# 998  Mastercard  S.V.|880-5987      No      No             48
# 999  Mastercard  S.V.|880-5987      No      No             48
#
#     Parking Validation?  Profit Percent  Profit
# 0                    No       48.040201    4.78
# 1                    No       34.989980   43.65
# 2                   Yes       48.067227    2.86
# 3                    No       54.974874    5.47
# 4                    No       48.040201    4.78
# ..                  ...             ...     ...
# 995                  No       48.040201    9.56
# 996                  No       49.090909   12.15
# 997                  No       48.067227    2.86
# 998                  No       54.974874   10.94
# 999                  No       48.040201    4.78
#
# [1000 rows x 20 columns]

# %%
df['Toy Company'].unique()
# Out:
# <StringArray>
# ['Duplo', 'Lego']
# Length: 2, dtype: str

# %%
df['Toy Company'].value_counts()
# Out:
# Toy Company
# Duplo    593
# Lego     407
# Name: count, dtype: int64

# %%
df.groupby('Toy Company')['Profit'].sum()
# Out:
# Toy Company
# Duplo    5196.79
# Lego     3468.02
# Name: Profit, dtype: float64

# %%
df.groupby('Toy Name')['Profit'].sum()
# Out:
# Toy Name
# Airplane                          1043.90
# Antique Car                         52.50
# Cowboys with Horses                 96.40
# Family                              98.70
# Farming Scene                      331.74
# Fire Trucks                        210.42
# Gas Station                        221.44
# Police Officers and Motorcycle    1695.70
# Policemen                         4780.00
# Scooter                             85.05
# Scooter and Stand                   48.96
# Name: Profit, dtype: float64

# %%
df.groupby('Payment')['Total Line Revenue'].sum()
# Out:
# Payment
# Cash          4351.00
# Check         1022.45
# Discover      1262.40
# Gift Card     1371.65
# Mastercard    3882.70
# Visa          6075.50
# Name: Total Line Revenue, dtype: float64

# %%
df.groupby('Payment')['Total Line Revenue'].count()
# Out:
# Payment
# Cash          240
# Check          56
# Discover       74
# Gift Card      68
# Mastercard    221
# Visa          341
# Name: Total Line Revenue, dtype: int64

# %%
df.groupby('Payment')['Total Line Revenue'].mean()
# Out:
# Payment
# Cash          18.129167
# Check         18.258036
# Discover      17.059459
# Gift Card     20.171324
# Mastercard    17.568778
# Visa          17.816716
# Name: Total Line Revenue, dtype: float64

# %%
print(pd.crosstab(df["Member?"], df["Coupon?"], margins=True, margins_name="Total"))
# Out:
# Coupon?   No  Yes  Total
# Member?
# No       791   90    881
# Yes       80   39    119
# Total    871  129   1000

# %%
(pd.crosstab(df["Member?"], df["Payment"], normalize="index") * 100).round(1)
# Out:
# Payment  Cash  Check  Discover  Gift Card  Mastercard  Visa
# Member?
# No       24.5    5.2       7.5        6.9        21.3  34.5
# Yes      20.2    8.4       6.7        5.9        27.7  31.1

# %%
(pd.crosstab(df["Payment"], df["Member?"], normalize="index") * 100).round(1)
# Out:
# Member?       No   Yes
# Payment
# Cash        90.0  10.0
# Check       82.1  17.9
# Discover    89.2  10.8
# Gift Card   89.7  10.3
# Mastercard  85.1  14.9
# Visa        89.1  10.9

# %%
pd.pivot_table(
    data=df,
    values="Total Line Revenue",
    index="Toy Company",
    columns="Payment",
    aggfunc="sum",
    fill_value=0
)
# Out:
# Payment         Cash   Check  Discover  Gift Card  Mastercard     Visa
# Toy Company
# Duplo        2557.05  641.90     806.1     806.10     2592.65  3667.55
# Lego         1793.95  380.55     456.3     565.55     1290.05  2407.95

# %%
df["Total Line Revenue"] = df["Total Line Revenue"].astype(str).str.replace("$", "", regex=False).str.strip().astype(float)

# 2. Aggregate total revenue per toy name
toy_sales = df.groupby("Toy Name")["Total Line Revenue"].sum().sort_values(ascending=True)

# 3. Create Figure and Axes (Object-Oriented API)
fig, ax = plt.subplots(figsize=(10, 6))

# 4. Plot horizontal bars

bars = ax.barh(toy_sales.index, toy_sales.values, color="#1f77b4", edgecolor="black", height=0.65)

# 5. Styling and labels
ax.set_title("Total Revenue Generated by Toy Name (2010 - 2012)", fontsize=14, fontweight="bold", pad=15)
ax.set_xlabel("Total Revenue (USD $)", fontsize=12)
ax.set_ylabel("Toy Name", fontsize=12)
ax.grid(axis="x", linestyle="--", alpha=0.7)

# 6. Add formatted value annotations to the right of each bar
for bar in bars:
    width = bar.get_width()
    ax.text(width + 80, bar.get_y() + bar.get_height() / 2, f"${width:,.2f}",
            va="center", ha="left", fontsize=9, fontweight="medium")

# Expand x-limit to prevent text clipping
ax.set_xlim(0, max(toy_sales.values) * 1.15)

plt.tight_layout()
plt.savefig("images/chart1_revenue_by_toy.png", dpi=200)
plt.show()

# %%
df["Total Line Revenue"] = df["Total Line Revenue"].astype(str).str.replace("$", "", regex=False).str.strip().astype(float)
df.groupby("Toy Name")["Total Line Revenue"].sum().sort_values(ascending=True)
# Out:
# Toy Name
# Scooter and Stand                   89.10
# Antique Car                        119.25
# Scooter                            173.25
# Cowboys with Horses                189.00
# Family                             224.25
# Fire Trucks                        489.30
# Gas Station                        527.20
# Farming Scene                      948.10
# Airplane                          2171.75
# Police Officers and Motorcycle    3084.50
# Policemen                         9950.00
# Name: Total Line Revenue, dtype: float64
